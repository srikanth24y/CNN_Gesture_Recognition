# %% [markdown]
# **Problem statement:** To develop a cool feature in the smart-TV that can recognize five different gestures performed by the user which will help users control the TV without using a remote.
#
# <table>
#   <thead>
#     <tr>
#       <th>Gesture</th>
#       <th>Action</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Thumbs up</td>
#       <td>Increase volume</td>
#     </tr>
#     <tr>
#       <td>Thumbs down</td>
#       <td>Reduce volume</td>
#     </tr>
#     <tr>
#       <td>Right swipe</td>
#       <td>Jump forward 10 secs</td>
#     </tr>
#     <tr>
#       <td>Left swipe</td>
#       <td>Jump backward 10 secs</td>
#     </tr>
#     <tr>
#       <td>Stop</td>
#       <td>Pause the movie</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Importing all the important libraries

# %%
import numpy as np
import os
from imageio import imread
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
# from scipy.misc import imresize

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip  '/content/drive/My Drive/Project_data.zip' -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00050.png
#  extracting: /content/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00052.png
#  extracting: /content/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00054.png
#  extracting: /content/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00056.png
#  extracting: /content/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00058.png
#  extracting: /content/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00060.png
#  extracting: /content/Project_data/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00062.png
#    creating: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00001.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00003.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00005.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00007.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00009.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00011.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00013.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00015.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00017.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00019.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00021.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00023.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00025.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00027.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00029.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00031.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00033.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00035.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00037.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00039.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00041.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00043.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00045.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00047.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00049.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00051.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00053.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00055.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00057.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00059.png
#    creating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00004.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00006.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00008.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00010.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00012.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00014.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00016.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00018.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00020.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00022.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00024.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00026.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00028.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00030.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00032.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00034.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00036.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00038.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00040.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00042.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00044.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00046.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00048.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00050.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00052.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00054.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00056.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00058.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00060.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00062.png
#    creating: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00015.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00016.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00017.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00018.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00019.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00020.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00021.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00022.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00023.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00024.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00025.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00026.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00027.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00028.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00029.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00030.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00031.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00032.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00033.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00034.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00035.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00036.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00037.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00038.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00039.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00040.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00041.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00042.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00043.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00044.png
#    creating: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00006.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00008.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00010.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00012.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00014.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00016.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00018.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00020.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00022.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00024.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00026.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00028.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00030.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00032.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00034.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00036.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00038.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00040.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00042.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00044.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00046.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00048.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00050.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00052.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00054.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00056.png
#   inflating: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00058.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00060.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00062.png
#  extracting: /content/Project_data/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00064.png
#    creating: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00003.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00005.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00007.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00009.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00011.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00013.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00015.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00017.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00019.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00021.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00023.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00025.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00027.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00029.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00031.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00033.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00035.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00037.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00039.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00041.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00043.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00045.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00047.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00049.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00051.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00053.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00055.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00057.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00059.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00061.png
#    creating: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00005.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00007.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00009.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00011.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00013.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00015.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00017.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00019.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00021.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00023.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00025.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00027.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00029.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00031.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00033.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00035.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00037.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00039.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00041.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00043.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00045.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00047.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00049.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00051.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00053.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00055.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00057.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00059.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00061.png
#  extracting: /content/Project_data/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00063.png
#    creating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00013.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00015.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00017.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00019.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00021.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00023.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00025.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00027.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00029.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00031.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00033.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00035.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00037.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00039.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00041.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00043.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00045.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00047.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00049.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00051.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00053.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00055.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00057.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00059.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00061.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00063.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00065.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00067.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00069.png
#   inflating: /content/Project_data/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00071.png
#    creating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00001.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00003.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00005.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00007.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00009.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00011.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00013.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00015.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00017.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00019.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00021.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00023.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00025.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00027.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00029.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00031.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00033.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00035.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00037.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00039.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00041.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00043.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00045.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00047.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00049.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00051.png
#   inflating: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00053.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00055.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00057.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00059.png
#    creating: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00003.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00006.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00009.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00012.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00015.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00018.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00021.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00024.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00027.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00030.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00033.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00036.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00039.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00042.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00045.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00048.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00051.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00054.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00057.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00060.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00063.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00066.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00069.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00072.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00075.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00078.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00081.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00084.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00087.png
#  extracting: /content/Project_data/train/WIN_20180926_17_37_45_Pro_Left_Swipe_new/WIN_20180926_17_37_45_Pro_00090.png
#    creating: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00006.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00009.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00012.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00015.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00018.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00021.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00024.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00027.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00030.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00033.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00036.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00039.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00042.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00045.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00048.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00051.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00054.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00057.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00060.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00063.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00066.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00069.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00072.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00075.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00078.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00081.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00084.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00087.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00090.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_09_Pro_Left_Swipe_new/WIN_20180926_17_38_09_Pro_00093.png
#    creating: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00007.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00009.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00011.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00013.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00015.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00017.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00019.png
#   inflating: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00021.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00023.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00025.png
#   inflating: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00027.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00029.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00031.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00033.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00035.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00037.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00039.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00041.png
#   inflating: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00043.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00045.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00047.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00049.png
#   inflating: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00051.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00053.png
#   inflating: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00055.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00057.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00059.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00061.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00063.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_25_Pro_Stop_new/WIN_20180926_17_38_25_Pro_00065.png
#    creating: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00011.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00013.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00015.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00017.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00019.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00021.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00023.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00025.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00027.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00029.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00031.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00033.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00035.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00037.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00039.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00041.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00043.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00045.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00047.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00049.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00051.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00053.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00055.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00057.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00059.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00061.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00063.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00065.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00067.png
#  extracting: /content/Project_data/train/WIN_20180926_17_38_34_Pro_Right_Swipe_new/WIN_20180926_17_38_34_Pro_00069.png
#    creating: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00003.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00005.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00007.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00009.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00011.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00013.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00015.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00017.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00019.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00021.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00023.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00025.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00027.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00029.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00031.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00033.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00035.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00037.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00039.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00041.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00043.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00045.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00047.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00049.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00051.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00053.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00055.png
#  extracting: /content/Project_data/train/WIN_20180926_17_39_05_Pro_Stop_new/WIN_20180926_17_39_05_Pro_00057.png
# ...
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00042.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00044.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00046.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00048.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00050.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00052.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00054.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00056.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00058.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00060.png
#  extracting: /content/Project_data/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00062.png
#    creating: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00007.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00009.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00011.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00013.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00015.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00017.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00019.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00021.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00023.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00025.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00027.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00029.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00031.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00033.png
#   inflating: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00035.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00037.png
#   inflating: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00039.png
#   inflating: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00041.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00043.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00045.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00047.png
#   inflating: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00049.png
#   inflating: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00051.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00053.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00055.png
#   inflating: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00057.png
#   inflating: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00059.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00061.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00063.png
#  extracting: /content/Project_data/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00065.png
#    creating: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00009.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00011.png
#   inflating: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00013.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00015.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00017.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00019.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00021.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00023.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00025.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00027.png
#   inflating: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00029.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00031.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00033.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00035.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00037.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00039.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00041.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00043.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00045.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00047.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00049.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00051.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00053.png
#   inflating: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00055.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00057.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00059.png
#   inflating: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00061.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00063.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00065.png
#  extracting: /content/Project_data/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00067.png
#    creating: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00001.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00003.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00005.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00007.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00009.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00011.png
#   inflating: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00013.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00015.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00017.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00019.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00021.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00023.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00025.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00027.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00029.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00031.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00033.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00035.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00037.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00039.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00041.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00043.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00045.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00047.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00049.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00051.png
#   inflating: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00053.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00055.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00057.png
#  extracting: /content/Project_data/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00059.png
#    creating: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00009.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00011.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00013.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00015.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00017.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00019.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00021.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00023.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00025.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00027.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00029.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00031.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00033.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00035.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00037.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00039.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00041.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00043.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00045.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00047.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00049.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00051.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00053.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00055.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00057.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00059.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00061.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00063.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00065.png
#  extracting: /content/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00067.png

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the batch_size here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train and validatiaon data creator with ablation, when ablation is 10, then 10 folders for each label will be selected.
def getdata(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1 
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = getdata('/content/Project_data/', ablation=None)
batch_size = 32 #experiment with the batch size
enable_augmentation = False # augmentation of Data

# %% [markdown]
# ### Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with img_idx, y,z and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug_mode = False):
    # print( 'Source path = ', source_path, '; batch size =', batch_size)
    # selecting alternate frames from 8 to 27
    img_idx = range(7,26,2) #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    # image dimensions
    y, z = 120, 120
    while True:
        # double the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)
        num_batches = int(len(t)/batch_size) if (len(t)%batch_size) == 0 else len(t)//batch_size + 1 # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug_mode:
                    plt.figure(figsize=(18,6))
                # handling remaining datapoints
                folder_idx = folder + (batch * batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                # print('source_path', source_path)
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                augmentation_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    augmentation_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    if debug_mode:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))
                        
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # converting rectangle images into square by cropping sides, so to maintain aspect ratio
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    # resized_im = imresize(image, size=(y,z))
                    resized_im = np.array(Image.fromarray(image.astype(np.uint8)).resize((y,z)))
                    
                    if augmentation_type is not None:
                        resized_im = getimagefilter(resized_im, augmentation_type)
                    
                    if debug_mode:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)
                        
                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image
                    
                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %%
def getimagefilter(resized_im, augtype):
    if augtype == 0: # edge Enhancement
        resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
    elif augtype == 1: # adding gaussian blur
        resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
    elif augtype == 2: # enchancing image detailing
        resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
    elif augtype == 3: # sharpening image
        resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
    elif augtype == 4: # Brightness enhancement
        augtype = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
    return resized_im

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'

num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
test_generator = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug_mode = True)
d = next(test_generator)[0]

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers.convolutional import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

# %%
img_idx = range(7,26,2)
# image dimensions
y, z = 120, 120
input_shape = (len(img_idx), y, z, 3)
np.random.seed(50)

# %% [markdown]
# ### Exercise 1

# %%
# Convolution 3D
model = Sequential()

model.add(Conv3D(32, kernel_size=3, input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=2))

model.add(Conv3D(64, kernel_size=3))
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=2))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Exercise 2

# %%
# Convolution 3D
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Exercise 3

# %%
# Convolution 3D, BatchNormalization
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())

model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Exercise 4

# %%
# Convolution 3D, Dropouts
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Exercise 5

# %%
# Convolution 3D, Dropouts
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Exercise 6

# %%
# TimeDistributed Convolution 2D & GRU
model = Sequential()
model.add(TimeDistributed(Conv2D(32, (3,3), activation='relu'), input_shape=input_shape))
model.add(TimeDistributed(MaxPooling2D((2,2))))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(TimeDistributed(Conv2D(64, (3,3), activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2,2))))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(TimeDistributed(GlobalAveragePooling2D()))
model.add(TimeDistributed(Dense(64, activation='relu')))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(GRU(128))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Exercise 7

# %%
# TimeDistributed Convolution 2D & Dense
model = Sequential()
model.add(TimeDistributed(Conv2D(32, (3,3), activation='relu'), input_shape=input_shape))
model.add(TimeDistributed(MaxPooling2D((2,2))))
model.add(BatchNormalization())

model.add(TimeDistributed(Conv2D(64, (3,3), activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2,2))))
model.add(BatchNormalization())

model.add(TimeDistributed(Conv2D(128, (3,3), activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2,2))))
model.add(BatchNormalization())

model.add(GlobalAveragePooling3D())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Exercise 8

# %%
# TimeDistributed Convolution LSTM2D

model = Sequential()
model.add(TimeDistributed(Conv2D(8, (3,3), activation='relu'), input_shape=input_shape))
model.add(BatchNormalization())

model.add(TimeDistributed(Conv2D(16, (3,3), activation='relu')))
model.add(BatchNormalization())

model.add(ConvLSTM2D(8, kernel_size = 3, return_sequences=False))
model.add(BatchNormalization())

model.add(TimeDistributed(Dense(64, activation='relu')))
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())

model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Final Model

# %%
# TimeDistributed Convolution 2D & Dense
model = Sequential()
model.add(TimeDistributed(Conv2D(32, (3,3), activation='relu'), input_shape=input_shape))
model.add(TimeDistributed(MaxPooling2D((2,2))))
model.add(BatchNormalization())

model.add(TimeDistributed(Conv2D(64, (3,3), activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2,2))))
model.add(BatchNormalization())

model.add(TimeDistributed(Conv2D(128, (3,3), activation='relu')))
model.add(TimeDistributed(MaxPooling2D((2,2))))
model.add(BatchNormalization())

model.add(GlobalAveragePooling3D())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to compile the model. When you print the summary of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_33 (TimeDi  (None, 10, 118, 118, 32)  896
#  stributed)
#
#  time_distributed_34 (TimeDi  (None, 10, 59, 59, 32)   0
#  stributed)
#
#  batch_normalization_42 (Bat  (None, 10, 59, 59, 32)   128
#  chNormalization)
#
#  time_distributed_35 (TimeDi  (None, 10, 57, 57, 64)   18496
#  stributed)
#
#  time_distributed_36 (TimeDi  (None, 10, 28, 28, 64)   0
#  stributed)
#
#  batch_normalization_43 (Bat  (None, 10, 28, 28, 64)   256
#  chNormalization)
#
#  time_distributed_37 (TimeDi  (None, 10, 26, 26, 128)  73856
#  stributed)
#
#  time_distributed_38 (TimeDi  (None, 10, 13, 13, 128)  0
#  stributed)
#
#  batch_normalization_44 (Bat  (None, 10, 13, 13, 128)  512
#  chNormalization)
#
#  global_average_pooling3d_2   (None, 128)              0
#  (GlobalAveragePooling3D)
#
#  dense_29 (Dense)            (None, 256)               33024
#
#  batch_normalization_45 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_30 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 129,477
# Trainable params: 128,517
# Non-trainable params: 960
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init_Final' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 1.8559 - categorical_accuracy: 0.3601
# Epoch 1: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00001-1.85589-0.36012-19.73256-0.17969.h5
# 21/21 [==============================] - 26s 1s/step - loss: 1.8559 - categorical_accuracy: 0.3601 - val_loss: 19.7326 - val_categorical_accuracy: 0.1797 - lr: 0.0100
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2761 - categorical_accuracy: 0.4866
# Epoch 2: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00002-1.27612-0.48661-14.34985-0.17188.h5
# 21/21 [==============================] - 25s 1s/step - loss: 1.2761 - categorical_accuracy: 0.4866 - val_loss: 14.3498 - val_categorical_accuracy: 0.1719 - lr: 0.0100
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0124 - categorical_accuracy: 0.5699
# Epoch 3: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00003-1.01235-0.56994-8.85228-0.19531.h5
# 21/21 [==============================] - 25s 1s/step - loss: 1.0124 - categorical_accuracy: 0.5699 - val_loss: 8.8523 - val_categorical_accuracy: 0.1953 - lr: 0.0100
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9480 - categorical_accuracy: 0.6027
# Epoch 4: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00004-0.94796-0.60268-5.32115-0.19531.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.9480 - categorical_accuracy: 0.6027 - val_loss: 5.3211 - val_categorical_accuracy: 0.1953 - lr: 0.0100
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8948 - categorical_accuracy: 0.6488
# Epoch 5: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00005-0.89484-0.64881-5.73830-0.18750.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.8948 - categorical_accuracy: 0.6488 - val_loss: 5.7383 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8563 - categorical_accuracy: 0.6429
# Epoch 6: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00006-0.85633-0.64286-4.20400-0.17969.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.8563 - categorical_accuracy: 0.6429 - val_loss: 4.2040 - val_categorical_accuracy: 0.1797 - lr: 0.0100
# Epoch 7/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8379 - categorical_accuracy: 0.6488
# Epoch 7: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00007-0.83789-0.64881-2.01834-0.18750.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.8379 - categorical_accuracy: 0.6488 - val_loss: 2.0183 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 8/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7497 - categorical_accuracy: 0.6935
# Epoch 8: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00008-0.74966-0.69345-2.04170-0.21875.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.7497 - categorical_accuracy: 0.6935 - val_loss: 2.0417 - val_categorical_accuracy: 0.2188 - lr: 0.0100
# Epoch 9/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7801 - categorical_accuracy: 0.6890
# Epoch 9: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00009-0.78006-0.68899-2.59599-0.17969.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.7801 - categorical_accuracy: 0.6890 - val_loss: 2.5960 - val_categorical_accuracy: 0.1797 - lr: 0.0100
# Epoch 10/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7745 - categorical_accuracy: 0.7068
# Epoch 10: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00010-0.77454-0.70685-1.51539-0.25000.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.7745 - categorical_accuracy: 0.7068 - val_loss: 1.5154 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 11/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7626 - categorical_accuracy: 0.6830
# Epoch 11: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00011-0.76259-0.68304-1.44479-0.28906.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.7626 - categorical_accuracy: 0.6830 - val_loss: 1.4448 - val_categorical_accuracy: 0.2891 - lr: 0.0100
# Epoch 12/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8048 - categorical_accuracy: 0.6935
# Epoch 12: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00012-0.80476-0.69345-2.87436-0.24219.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.8048 - categorical_accuracy: 0.6935 - val_loss: 2.8744 - val_categorical_accuracy: 0.2422 - lr: 0.0100
# Epoch 13/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7065 - categorical_accuracy: 0.7143
# Epoch 13: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00013-0.70649-0.71429-2.00030-0.19531.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.7065 - categorical_accuracy: 0.7143 - val_loss: 2.0003 - val_categorical_accuracy: 0.1953 - lr: 0.0100
# Epoch 14/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7530 - categorical_accuracy: 0.6815
# Epoch 14: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00014-0.75304-0.68155-2.32360-0.25000.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.7530 - categorical_accuracy: 0.6815 - val_loss: 2.3236 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 15/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7398 - categorical_accuracy: 0.7173
# Epoch 15: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00015-0.73976-0.71726-10.10024-0.15625.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.7398 - categorical_accuracy: 0.7173 - val_loss: 10.1002 - val_categorical_accuracy: 0.1562 - lr: 0.0100
# Epoch 16/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7216 - categorical_accuracy: 0.7262
# Epoch 16: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00016-0.72164-0.72619-2.61188-0.19531.h5
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 21/21 [==============================] - 24s 1s/step - loss: 0.7216 - categorical_accuracy: 0.7262 - val_loss: 2.6119 - val_categorical_accuracy: 0.1953 - lr: 0.0100
# Epoch 17/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5572 - categorical_accuracy: 0.7649
# Epoch 17: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00017-0.55722-0.76488-1.66716-0.29688.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.5572 - categorical_accuracy: 0.7649 - val_loss: 1.6672 - val_categorical_accuracy: 0.2969 - lr: 0.0020
# Epoch 18/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4996 - categorical_accuracy: 0.7738
# Epoch 18: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00018-0.49961-0.77381-1.01690-0.46094.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.4996 - categorical_accuracy: 0.7738 - val_loss: 1.0169 - val_categorical_accuracy: 0.4609 - lr: 0.0020
# Epoch 19/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4324 - categorical_accuracy: 0.8185
# Epoch 19: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00019-0.43238-0.81845-1.07516-0.41406.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.4324 - categorical_accuracy: 0.8185 - val_loss: 1.0752 - val_categorical_accuracy: 0.4141 - lr: 0.0020
# Epoch 20/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4414 - categorical_accuracy: 0.8036
# Epoch 20: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00020-0.44143-0.80357-0.94202-0.43750.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.4414 - categorical_accuracy: 0.8036 - val_loss: 0.9420 - val_categorical_accuracy: 0.4375 - lr: 0.0020
# Epoch 21/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4353 - categorical_accuracy: 0.8065
# Epoch 21: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00021-0.43534-0.80655-1.09302-0.40625.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.4353 - categorical_accuracy: 0.8065 - val_loss: 1.0930 - val_categorical_accuracy: 0.4062 - lr: 0.0020
# Epoch 22/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4133 - categorical_accuracy: 0.8110
# Epoch 22: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00022-0.41334-0.81101-1.26141-0.35156.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.4133 - categorical_accuracy: 0.8110 - val_loss: 1.2614 - val_categorical_accuracy: 0.3516 - lr: 0.0020
# Epoch 23/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4021 - categorical_accuracy: 0.8348
# Epoch 23: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00023-0.40213-0.83482-1.24087-0.31250.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.4021 - categorical_accuracy: 0.8348 - val_loss: 1.2409 - val_categorical_accuracy: 0.3125 - lr: 0.0020
# Epoch 24/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3841 - categorical_accuracy: 0.8214
# Epoch 24: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00024-0.38415-0.82143-0.96676-0.42188.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.3841 - categorical_accuracy: 0.8214 - val_loss: 0.9668 - val_categorical_accuracy: 0.4219 - lr: 0.0020
# Epoch 25/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3735 - categorical_accuracy: 0.8542
# Epoch 25: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00025-0.37347-0.85417-0.73186-0.73438.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.3735 - categorical_accuracy: 0.8542 - val_loss: 0.7319 - val_categorical_accuracy: 0.7344 - lr: 0.0020
# Epoch 26/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3728 - categorical_accuracy: 0.8333
# Epoch 26: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00026-0.37282-0.83333-0.95082-0.58594.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.3728 - categorical_accuracy: 0.8333 - val_loss: 0.9508 - val_categorical_accuracy: 0.5859 - lr: 0.0020
# Epoch 27/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3549 - categorical_accuracy: 0.8438
# Epoch 27: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00027-0.35490-0.84375-0.57660-0.56250.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.3549 - categorical_accuracy: 0.8438 - val_loss: 0.5766 - val_categorical_accuracy: 0.5625 - lr: 0.0020
# Epoch 28/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3658 - categorical_accuracy: 0.8512
# Epoch 28: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00028-0.36576-0.85119-0.70708-0.67188.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.3658 - categorical_accuracy: 0.8512 - val_loss: 0.7071 - val_categorical_accuracy: 0.6719 - lr: 0.0020
# Epoch 29/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3638 - categorical_accuracy: 0.8512
# Epoch 29: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00029-0.36384-0.85119-0.57491-0.74219.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.3638 - categorical_accuracy: 0.8512 - val_loss: 0.5749 - val_categorical_accuracy: 0.7422 - lr: 0.0020
# Epoch 30/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2766 - categorical_accuracy: 0.8854
# Epoch 30: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00030-0.27662-0.88542-0.56562-0.73438.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.2766 - categorical_accuracy: 0.8854 - val_loss: 0.5656 - val_categorical_accuracy: 0.7344 - lr: 0.0020
# Epoch 31/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3089 - categorical_accuracy: 0.8854
# Epoch 31: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00031-0.30890-0.88542-0.54784-0.74219.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.3089 - categorical_accuracy: 0.8854 - val_loss: 0.5478 - val_categorical_accuracy: 0.7422 - lr: 0.0020
# Epoch 32/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2754 - categorical_accuracy: 0.8958
# Epoch 32: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00032-0.27538-0.89583-0.58723-0.72656.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.2754 - categorical_accuracy: 0.8958 - val_loss: 0.5872 - val_categorical_accuracy: 0.7266 - lr: 0.0020
# Epoch 33/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2777 - categorical_accuracy: 0.8824
# Epoch 33: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00033-0.27769-0.88244-0.47343-0.76562.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.2777 - categorical_accuracy: 0.8824 - val_loss: 0.4734 - val_categorical_accuracy: 0.7656 - lr: 0.0020
# Epoch 34/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2982 - categorical_accuracy: 0.8705
# Epoch 34: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00034-0.29825-0.87054-0.86364-0.71094.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.2982 - categorical_accuracy: 0.8705 - val_loss: 0.8636 - val_categorical_accuracy: 0.7109 - lr: 0.0020
# Epoch 35/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2446 - categorical_accuracy: 0.8810
# Epoch 35: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00035-0.24463-0.88095-1.37165-0.61719.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.2446 - categorical_accuracy: 0.8810 - val_loss: 1.3717 - val_categorical_accuracy: 0.6172 - lr: 0.0020
# Epoch 36/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2992 - categorical_accuracy: 0.8958
# Epoch 36: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00036-0.29925-0.89583-0.95714-0.67969.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.2992 - categorical_accuracy: 0.8958 - val_loss: 0.9571 - val_categorical_accuracy: 0.6797 - lr: 0.0020
# Epoch 37/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2901 - categorical_accuracy: 0.8943
# Epoch 37: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00037-0.29013-0.89435-1.08324-0.62500.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.2901 - categorical_accuracy: 0.8943 - val_loss: 1.0832 - val_categorical_accuracy: 0.6250 - lr: 0.0020
# Epoch 38/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2441 - categorical_accuracy: 0.9018
# Epoch 38: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00038-0.24412-0.90179-0.60615-0.72656.h5
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.001.
# 21/21 [==============================] - 24s 1s/step - loss: 0.2441 - categorical_accuracy: 0.9018 - val_loss: 0.6061 - val_categorical_accuracy: 0.7266 - lr: 0.0020
# Epoch 39/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2180 - categorical_accuracy: 0.9137
# Epoch 39: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00039-0.21797-0.91369-0.47373-0.82031.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.2180 - categorical_accuracy: 0.9137 - val_loss: 0.4737 - val_categorical_accuracy: 0.8203 - lr: 0.0010
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2225 - categorical_accuracy: 0.9196
# Epoch 40: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00040-0.22249-0.91964-0.39014-0.82812.h5
# 21/21 [==============================] - 23s 1s/step - loss: 0.2225 - categorical_accuracy: 0.9196 - val_loss: 0.3901 - val_categorical_accuracy: 0.8281 - lr: 0.0010
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1817 - categorical_accuracy: 0.9375
# Epoch 41: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00041-0.18172-0.93750-0.31126-0.85156.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.1817 - categorical_accuracy: 0.9375 - val_loss: 0.3113 - val_categorical_accuracy: 0.8516 - lr: 0.0010
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1879 - categorical_accuracy: 0.9167
# Epoch 42: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00042-0.18788-0.91667-0.37349-0.85156.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.1879 - categorical_accuracy: 0.9167 - val_loss: 0.3735 - val_categorical_accuracy: 0.8516 - lr: 0.0010
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1840 - categorical_accuracy: 0.9315
# Epoch 43: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00043-0.18400-0.93155-0.51974-0.83594.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.1840 - categorical_accuracy: 0.9315 - val_loss: 0.5197 - val_categorical_accuracy: 0.8359 - lr: 0.0010
# Epoch 44/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1913 - categorical_accuracy: 0.9345
# Epoch 44: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00044-0.19132-0.93452-0.31902-0.86719.h5
# 21/21 [==============================] - 23s 1s/step - loss: 0.1913 - categorical_accuracy: 0.9345 - val_loss: 0.3190 - val_categorical_accuracy: 0.8672 - lr: 0.0010
# Epoch 45/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2022 - categorical_accuracy: 0.9345
# Epoch 45: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00045-0.20221-0.93452-0.42032-0.84375.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.2022 - categorical_accuracy: 0.9345 - val_loss: 0.4203 - val_categorical_accuracy: 0.8438 - lr: 0.0010
# Epoch 46/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1501 - categorical_accuracy: 0.9301
# Epoch 46: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00046-0.15007-0.93006-0.34214-0.85156.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.1501 - categorical_accuracy: 0.9301 - val_loss: 0.3421 - val_categorical_accuracy: 0.8516 - lr: 0.0010
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1941 - categorical_accuracy: 0.9211
# Epoch 47: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00047-0.19409-0.92113-0.26372-0.87500.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.1941 - categorical_accuracy: 0.9211 - val_loss: 0.2637 - val_categorical_accuracy: 0.8750 - lr: 0.0010
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1584 - categorical_accuracy: 0.9390
# Epoch 48: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00048-0.15838-0.93899-0.37893-0.84375.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.1584 - categorical_accuracy: 0.9390 - val_loss: 0.3789 - val_categorical_accuracy: 0.8438 - lr: 0.0010
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1601 - categorical_accuracy: 0.9345
# Epoch 49: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00049-0.16013-0.93452-0.32688-0.64844.h5
# 21/21 [==============================] - 25s 1s/step - loss: 0.1601 - categorical_accuracy: 0.9345 - val_loss: 0.3269 - val_categorical_accuracy: 0.6484 - lr: 0.0010
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1633 - categorical_accuracy: 0.9479
# Epoch 50: saving model to model_init_Final_2022-11-1613_56_05.118620/model-00050-0.16335-0.94792-0.37862-0.88281.h5
# 21/21 [==============================] - 24s 1s/step - loss: 0.1633 - categorical_accuracy: 0.9479 - val_loss: 0.3786 - val_categorical_accuracy: 0.8828 - lr: 0.0010
